# %% [markdown]
# # BISFT Chatbot Runner (Colab Edition)
# This notebook allows you to run the **DeepSeek-R1-7B** model using Colab's free T4 GPU.
#
# ### 1. Set Runtime to GPU
# Go to **Runtime** > **Change runtime type** and select **T4 GPU**.

# %%
from google.colab import drive
drive.mount('/content/drive')

# 2. UNZIP your project (Update the path to where you uploaded your zip)
# !unzip -q "/content/drive/MyDrive/business-insights-and-sales-forecasting-tool.zip" -d /content/

# %%
# %cd /content/business-insights-and-sales-forecasting-tool
# !pip install -r requirements.txt
# !pip install bitsandbytes accelerate transformers

# %% [markdown]
# ### 3. Run the Chatbot
# We will use the **7B model** here since Colab has enough memory!

# %%
# We override the model selection to use the 7B version for Colab
import os
os.environ["USE_7B_MODEL"] = "True"

# !python -m src.chatbot.consultant_agent
